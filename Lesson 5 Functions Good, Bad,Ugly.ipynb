# %% [markdown]
# ## Ugly spaghetti

# %% [markdown]
# ![pasta.png](attachment:pasta.png)

# %% [markdown]
# This is a as bad as you can possibly imagine in terms of unmaintable spaghetti code

# %%
def do_stuff(item_name,weight_in_pounds,is_per_unit,province,total_cost,discount=0,apply_discount=False):

    if item_name=='bananes':
        price=0.99
        cost=weight_in_pounds*price
        cost=cost*1.05
        return cost
    elif item_name[0:5]=='biere':
        if weight_in_pounds==6:
            if item_name[6:]=='boreale rousse':
                price=9.99
                cost=price+weight_in_pounds*0.05
            elif item_name[4:]=='boreale noire':
                price=9.99
                #this week there is a discount on boreale noire
                if apply_discount==True:
                    cost=price*0.9+weight_in_pounds*0.05
            
            elif item_name[4:]=='Saison du tracteur':
                price=5.99
                cost=(price+0.3)*weight_in_pounds
                
                
        if item_name in ['bananes','jambon','oeufs','pain','patates','lait']:
            pass
        else:
            
            if province=='quebec':
                cost=cost*1.0975
            elif province=='ontario':
                cost=cost*1.06
            elif provine=='nova scotia':
                cost=cost*1.06
            
        
        if total_cost>10 and apply_discount==True:
            return cost-discount
        else:
            return cost
    
                   
        
        if weight_in_pounds==1:
            if item_name[4:]=='Saison du tracteur':
                price=5.99
                cost=(price+0.3)
            if item_name[4:]=='MacTavish':
                price=5.87
                cost=(price+0.3)
            if item_name[4:]=='Surfeur de apocalyspo':
                price=5.99
                cost=(price+0.3)
            if item_name[4:]=='Buteuse':
                price=7.99
                cost=(price+0.3)
            if item_name[4:]=='sang dencre':
                price=5.75
                cost=(price+0.3)
            if item_name[4:]=='perroquet ipa':
                price=4.99
                cost=(price+0.3)
            if item_name in ['bananes','jambon','oeufs','pain','patates','lait']:
                pass
            else:
                if province=='quebec':
                    cost=cost*1.097
                elif province=='ontario':
                    cost=cost*1.06
                elif provine=='nova scotia':
                    cost=cost*1.06
            return cost
            
        
            
    elif item_name=='chocolate':
        price=1.19
        if weight_in_pounds==0 and is_per_unit==True:
            cost=price
        else:
            cost=price*weight_in_pounds
           
        if item_name in ['bananes','jambon','oeufs','pain','patates','lait']:
            pass
        else:
            if province=='quebec':
                cost=cost*1.0975
            elif province=='ontario':
                cost=cost*1.06
            elif provine=='nova scotia':
                cost=cost*1.06
    
        cost=cost*1.05
        return cost

# %% [markdown]
# ## What is this doing????

# %%
do_stuff('chocolate',51,False,'quebec',50,2,True)
# Out:
# 69.93763874999999

# %%
tuple([1])
# Out:
# (1,)

# %%
def aa(key,*args):
    print(len(args))
    for a in args:
        
        print(a)
        
aa('abc',1,2,3)
# Out:
# 3
# 1
# 2
# 3

# %%
import datetime
from dateutil import relativedelta

# %%
d1=datetime.date(2021,1,1)
d2=datetime.date(2022,6,6)

# %%
relativedelta.relativedelta(d2, d1)
# Out:
# relativedelta(years=+1, months=+5, days=+5)

# %%
"{0:,.0f} $".format(1000).replace(',', ' ')
# Out:
# '1 000 $'

# %%
import QuantLib as ql

# %%
_month=12
_day=31
ql.Date(_day,_month,int(2011.0))
# Out:
# Date(31,12,2011)

# %%
"{:.1%}".format(0.25)

# %%
3+2

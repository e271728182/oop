# %% [markdown]
# # Lesson 1: Numbers,Strings and logical Operators

# %% [markdown]
# ![IMG_2358.tiff](attachment:IMG_2358.tiff)

# %% [markdown]
# ## part 1: add substract multiply and divide

# %% [markdown]
# Just try anything you want in this box

# %%
#exemple 1
a=2
b=3
#try other operations on a&b
c=a+b
print('a+b is equal to:', c)
# Out:
# a+b is equal to: 5

# %%
3+2
# Out:
# 5

# %% [markdown]
# ### Modulo

# %%
#modulo returns the reminder of a division see https://en.wikipedia.org/wiki/Modulo_operation
6%4
# Out:
# 2

# %% [markdown]
# ## part 2: Strings:

# %% [markdown]
# https://docs.python.org/3/library/string.html
# <br>Remember Strings always are between this symbol: ''

# %% [markdown]
# ### split

# %%
ma_liste="j'aime le poulet".split(' ')

# %% [markdown]
# ### replace

# %%
'jaime le poulet'.replace('poulet','jambon')
# Out:
# 'jaime le jambon'

# %% [markdown]
# ### concatenate a string

# %%
basic_string='my dog name is '
name_1='Leon'
name_2='axel'

basic_string+name_2
# Out:
# 'my dog name is axel'

# %% [markdown]
# ### Other interesting string operations

# %%
name='Boris'
string_to_find='Bo'

string_a_trouver in rre.lower()

# %% [markdown]
# ## part 3:logical operators

# %% [markdown]
# ### == operator

# %%
#to determine if to variable/elements are equal


3=='axel'
# Out:
# False

# %% [markdown]
# ### Or operator

# %%
#will return True if at least one of the element is True
statement_1=True
statement_2=False

statement_1 or statement_2
# Out:
# True

# %% [markdown]
# ### and operator

# %%
#will return True if all statements are True
statement_1=False
statement_2=False
statement_3=True

not statement_1 and statement_2 or not statement_3
# Out:
# False

# %% [markdown]
# ### not operator

# %%
#the not operator return the opposite of the value
not False
# Out:
# True

# %%
#example with variable
statement_3=False
not statement_3
# Out:
# True
